# %% [markdown]
# # GPM 데이터 다운로드
# Python 내장 라이브러리를 사용한 NASA GESDISC GPM 데이터 다운로드 예제

# %%
import os
import urllib.request
import http.cookiejar
from datetime import datetime, timedelta

# %%
def download_gpm_file(url, output_folder):
    """
    Download GPM file from NASA GESDISC using urllib with cookie handling
    
    Args:
        url (str): URL of the GPM file
        output_folder (str): Folder to save the downloaded file
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        
    filename = url.split('/')[-1]
    output_path = os.path.join(output_folder, filename)
    
    try:
        username = "rlawngns66"
        password = "Wogh+1027"
        
        # Create a password manager and cookie jar
        password_mgr = urllib.request.HTTPPasswordMgrWithDefaultRealm()
        password_mgr.add_password(None, "https://urs.earthdata.nasa.gov", username, password)
        
        # Create cookie jar and handlers
        cookie_jar = http.cookiejar.CookieJar()
        cookie_handler = urllib.request.HTTPCookieProcessor(cookie_jar)
        password_handler = urllib.request.HTTPBasicAuthHandler(password_mgr)
        
        # Build opener with both handlers
        opener = urllib.request.build_opener(cookie_handler, password_handler)
        
        # Install the opener
        urllib.request.install_opener(opener)
        
        # Download the file
        print(f"Downloading {filename}...")
        request = urllib.request.Request(url)
        with opener.open(request) as response:
            with open(output_path, 'wb') as out_file:
                out_file.write(response.read())
        print(f"Downloaded {filename} successfully")
        
    except Exception as e:
        print(f"Error downloading file: {str(e)}")
        raise

# %%
def generate_gpm_urls(start, end):
    """
    Generate URLs for GPM files between start and end dates
    """
    base_url = "https://gpm1.gesdisc.eosdis.nasa.gov/data/GPM_L3/GPM_3IMERGHHE.07"
    urls = []
    
    # Convert string dates to datetime objects
    start = datetime.strptime(start, "%Y%m%d")
    end = datetime.strptime(end, "%Y%m%d")
    
    current_date = start
    while current_date <= end:
        # GPM data is available every 30 minutes (48 files per day)
        index = 0  # Start index for each day (0000, 0030, 0060, ...)
        
        for hour in range(24):
            for minute in [0, 30]:
                # Format the date and time components
                year = current_date.strftime('%Y')
                doy = current_date.strftime('%j')
                date_str = current_date.strftime('%Y%m%d')
                
                # Create the filename
                start_time = f"{hour:02d}{minute:02d}00"
                
                # Calculate end time properly
                if minute == 0:
                    end_hour = hour
                    end_minute = 29
                else:
                    end_hour = hour
                    end_minute = 59
                
                end_time = f"{end_hour:02d}{end_minute:02d}59"
                
                # Format index as 4 digits (0000, 0030, 0060, ...)
                index_str = f"{index:04d}"
                
                filename = f"3B-HHR-E.MS.MRG.3IMERG.{date_str}-S{start_time}-E{end_time}.{index_str}.V07B.HDF5"
                
                # Construct the full URL
                url = f"{base_url}/{year}/{doy}/{filename}"
                urls.append(url)
                
                # Increment index by 30 for next file
                index += 30
        
        current_date += timedelta(days=1)
    
    return urls

# %%
def download_gpm_files(start_date, end_date, output_folder):
    """
    Download GPM files for a specific date range
    
    Args:
        start_date (str): Start date in 'YYYYMMDD' format
        end_date (str): End date in 'YYYYMMDD' format
        output_folder (str): Folder to save the downloaded files
    """
    urls = generate_gpm_urls(start_date, end_date)
    total_files = len(urls)
    
    print(f"Found {total_files} files to download")
    
    for i, url in enumerate(urls, 1):
        try:
            print(f"\nDownloading file {i}/{total_files}")
            download_gpm_file(url, output_folder)
        except Exception as e:
            print(f"Error downloading {url}: {str(e)}")
            continue

# %%
# 예제 사용
start_date = "20240117"  # 2024년 1월 17일
end_date = "20240117"    # 2024년 1월 17일
output_folder = "../data/GPM"

download_gpm_files(start_date, end_date, output_folder)
# Out:
# Found 48 files to download
#
# Downloading file 1/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S000000-E002959.0000.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S000000-E002959.0000.V07B.HDF5 successfully
#
# Downloading file 2/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S003000-E005959.0030.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S003000-E005959.0030.V07B.HDF5 successfully
#
# Downloading file 3/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S010000-E012959.0060.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S010000-E012959.0060.V07B.HDF5 successfully
#
# Downloading file 4/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S013000-E015959.0090.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S013000-E015959.0090.V07B.HDF5 successfully
#
# Downloading file 5/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S020000-E022959.0120.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S020000-E022959.0120.V07B.HDF5 successfully
#
# Downloading file 6/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S023000-E025959.0150.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S023000-E025959.0150.V07B.HDF5 successfully
#
# Downloading file 7/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S030000-E032959.0180.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S030000-E032959.0180.V07B.HDF5 successfully
#
# Downloading file 8/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S033000-E035959.0210.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S033000-E035959.0210.V07B.HDF5 successfully
#
# Downloading file 9/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S040000-E042959.0240.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S040000-E042959.0240.V07B.HDF5 successfully
#
# Downloading file 10/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S043000-E045959.0270.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S043000-E045959.0270.V07B.HDF5 successfully
#
# Downloading file 11/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S050000-E052959.0300.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S050000-E052959.0300.V07B.HDF5 successfully
#
# Downloading file 12/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S053000-E055959.0330.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S053000-E055959.0330.V07B.HDF5 successfully
#
# Downloading file 13/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S060000-E062959.0360.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S060000-E062959.0360.V07B.HDF5 successfully
#
# Downloading file 14/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S063000-E065959.0390.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S063000-E065959.0390.V07B.HDF5 successfully
#
# Downloading file 15/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S070000-E072959.0420.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S070000-E072959.0420.V07B.HDF5 successfully
#
# Downloading file 16/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S073000-E075959.0450.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S073000-E075959.0450.V07B.HDF5 successfully
#
# Downloading file 17/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S080000-E082959.0480.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S080000-E082959.0480.V07B.HDF5 successfully
#
# Downloading file 18/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S083000-E085959.0510.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S083000-E085959.0510.V07B.HDF5 successfully
#
# Downloading file 19/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S090000-E092959.0540.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S090000-E092959.0540.V07B.HDF5 successfully
#
# Downloading file 20/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S093000-E095959.0570.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S093000-E095959.0570.V07B.HDF5 successfully
#
# Downloading file 21/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S100000-E102959.0600.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S100000-E102959.0600.V07B.HDF5 successfully
#
# Downloading file 22/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S103000-E105959.0630.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S103000-E105959.0630.V07B.HDF5 successfully
#
# Downloading file 23/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S110000-E112959.0660.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S110000-E112959.0660.V07B.HDF5 successfully
#
# Downloading file 24/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S113000-E115959.0690.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S113000-E115959.0690.V07B.HDF5 successfully
#
# Downloading file 25/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S120000-E122959.0720.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S120000-E122959.0720.V07B.HDF5 successfully
#
# Downloading file 26/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S123000-E125959.0750.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S123000-E125959.0750.V07B.HDF5 successfully
#
# Downloading file 27/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S130000-E132959.0780.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S130000-E132959.0780.V07B.HDF5 successfully
#
# Downloading file 28/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S133000-E135959.0810.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S133000-E135959.0810.V07B.HDF5 successfully
#
# Downloading file 29/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S140000-E142959.0840.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S140000-E142959.0840.V07B.HDF5 successfully
#
# Downloading file 30/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S143000-E145959.0870.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S143000-E145959.0870.V07B.HDF5 successfully
#
# Downloading file 31/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S150000-E152959.0900.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S150000-E152959.0900.V07B.HDF5 successfully
#
# Downloading file 32/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S153000-E155959.0930.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S153000-E155959.0930.V07B.HDF5 successfully
#
# Downloading file 33/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S160000-E162959.0960.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S160000-E162959.0960.V07B.HDF5 successfully
#
# Downloading file 34/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S163000-E165959.0990.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S163000-E165959.0990.V07B.HDF5 successfully
#
# Downloading file 35/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S170000-E172959.1020.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S170000-E172959.1020.V07B.HDF5 successfully
#
# Downloading file 36/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S173000-E175959.1050.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S173000-E175959.1050.V07B.HDF5 successfully
#
# Downloading file 37/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S180000-E182959.1080.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S180000-E182959.1080.V07B.HDF5 successfully
#
# Downloading file 38/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S183000-E185959.1110.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S183000-E185959.1110.V07B.HDF5 successfully
#
# Downloading file 39/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S190000-E192959.1140.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S190000-E192959.1140.V07B.HDF5 successfully
#
# Downloading file 40/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S193000-E195959.1170.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S193000-E195959.1170.V07B.HDF5 successfully
#
# Downloading file 41/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S200000-E202959.1200.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S200000-E202959.1200.V07B.HDF5 successfully
#
# Downloading file 42/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S203000-E205959.1230.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S203000-E205959.1230.V07B.HDF5 successfully
#
# Downloading file 43/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S210000-E212959.1260.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S210000-E212959.1260.V07B.HDF5 successfully
#
# Downloading file 44/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S213000-E215959.1290.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S213000-E215959.1290.V07B.HDF5 successfully
#
# Downloading file 45/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S220000-E222959.1320.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S220000-E222959.1320.V07B.HDF5 successfully
#
# Downloading file 46/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S223000-E225959.1350.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S223000-E225959.1350.V07B.HDF5 successfully
#
# Downloading file 47/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S230000-E232959.1380.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S230000-E232959.1380.V07B.HDF5 successfully
#
# Downloading file 48/48
# Downloading 3B-HHR-E.MS.MRG.3IMERG.20240117-S233000-E235959.1410.V07B.HDF5...
# Downloaded 3B-HHR-E.MS.MRG.3IMERG.20240117-S233000-E235959.1410.V07B.HDF5 successfully
